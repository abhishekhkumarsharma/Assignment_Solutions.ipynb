# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekhkumarsharma/Assignment_Solutions.ipynb/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("### Demo Project: Analyzing Patterns, Trends, and Insights ###\n")

# 1. Display Basic Information about the Dataset
print("1. Dataset Information:")
print(df.info())
print("\n")

# 2. Display Descriptive Statistics
print("2. Descriptive Statistics:")
print(df.describe())
print("\n")

# 3. Visualize Distributions of Individual Columns (Patterns and Trends)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(df['col1'], kde=True)
plt.title('Distribution of col1')
plt.xlabel('col1 Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.histplot(df['col2'], kde=True)
plt.title('Distribution of col2')
plt.xlabel('col2 Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

print("\nInsights from Distributions:\n")
print("- The histograms help us understand the spread and central tendency of each numerical column.")
print("- We can observe if data is normally distributed, skewed, or has multiple peaks (modes).")
print("- For example, if 'col1' represented customer spending, its distribution could show common spending habits.")
print("\n")

# 4. Visualize Relationships Between Columns (Insights for Decision-Making)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='col1', y='col2')
plt.title('Scatter Plot of col1 vs col2')
plt.xlabel('col1')
plt.ylabel('col2')
plt.grid(True)
plt.show()

print("\nInsights from Relationships:\n")
print("- The scatter plot helps identify relationships or correlations between two variables.")
print("- A clear upward or downward trend suggests a positive or negative correlation.")
print("- Outliers (points far from the main cluster) might indicate unusual data points worth investigating.")
print("- For decision-making, if 'col1' influences 'col2', understanding this relationship can help in predicting outcomes or making strategic choices.")
print("\nExample Decision-Making Scenario:\n")
print("Imagine 'col1' is advertising spend and 'col2' is sales revenue. From these analyses:")
print("1. The distribution of advertising spend (col1) shows typical budget allocations.")
print("2. The distribution of sales revenue (col2) indicates common revenue ranges.")
print("3. A positive correlation in the scatter plot between 'col1' and 'col2' would suggest that increasing advertising spend tends to increase sales revenue. This insight would support decisions to invest more in advertising.")
print("\nThis is a basic demo. Further analysis would involve more advanced statistical tests, machine learning models, and domain-specific context.")
# Out:
# ### Demo Project: Analyzing Patterns, Trends, and Insights ###
#
# 1. Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    10 non-null     int64
#  1   col2    10 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 292.0 bytes
# None
#
#
# 2. Descriptive Statistics:
#             col1       col2
# count  10.000000  10.000000
# mean   48.000000   0.439610
# std    33.569166   0.297102
# min     5.000000   0.052421
# 25%    23.250000   0.184115
# 50%    42.500000   0.406226
# 75%    76.500000   0.668741
# max    98.000000   0.903169
# Insights from Distributions:
#
# - The histograms help us understand the spread and central tendency of each numerical column.
# - We can observe if data is normally distributed, skewed, or has multiple peaks (modes).
# ...
